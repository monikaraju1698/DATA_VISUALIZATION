# %%
###importing necessary library for data analysis and data visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
###matplotlibrary practice

# %%
x=[1,2,3,4,5,6,7]
y=[2,3,4,5,6,7,8]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.axis([0,10,0,10])
plt.title("PLOTTING 2D GRAPH")
plt.show()

# %%
from matplotlib.figure import Figure
fig=plt.figure(figsize=(3,3))
ax1=fig.add_axes([1,1,1,1])
ax2=fig.add_axes([0.5,0.5,0.5,0.5])
ax1.plot([2, 3, 4, 5, 5, 6, 6], [5, 7, 1, 3, 4, 6 ,8])
ax2.plot([1, 2, 3, 4, 5], [2, 3, 4, 5, 6])
  
plt.show()

# %%
axes=plt.axes([1,1,1,1])

# %%
fig=plt.figure(figsize=(3,3))
axes=fig.add_axes([1,1,1,1])
x=axes.plot([1,2,3,4],[1,2,3,4])
y=axes.plot([2,3,4,5],[1,2,3,4])
plt.show()

# %%
fig=plt.figure(figsize=(3,3))
ax1=fig.add_axes([1,1,1,1])
ax2=fig.add_axes([0.5,0.5,0.5,0.5])
x=ax1.plot([1,2,3,4,5],[2,4,6,8,10])
y=ax2.plot([2,4,6,8,10],[1,3,5,7,9])
plt.show()

# %%
x=[1,2,3,4]
y=[2,4,6,8]
z=[1,3,5,7]

plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(x,z)
plt.show()

# %%
fig=plt.figure(figsize=(1,1))
ax=fig.add_axes([1,6,1,6])
ax.plot(x,y)
x = [3, 1, 3] 
y = [3, 2, 1] 
ax.set_xticklabels(("one","two","three","four","five","six","seven","eight","nine","ten"))
# Out:
# <ipython-input-27-234dd9aae5ba>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(("one","two","three","four","five","six","seven","eight","nine","ten"))
# [Text(0.0, 0, 'one'),
#  Text(1.0, 0, 'two'),
#  Text(2.0, 0, 'three'),
#  Text(3.0, 0, 'four'),
#  Text(4.0, 0, 'five')]

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_axes([1,1,1,1])
plt.subplot(121)
ax.plot([1,2,3,4],[2,4,6,8])
plt.subplot(122)
ax.plot([2,3,4,5],[3,5,6,7])
plt.show()

# %%
import matplotlib.pyplot as plt 
  
# Creating the figure and subplots
# according the argument passed
fig, axes = plt.subplots(1, 2)
  
# plotting the data in the 1st subplot
axes[0].plot([1, 2, 3, 4], [1, 2, 3, 4])
  
# plotting the data in the 1st subplot only
axes[0].plot([1, 2, 3, 4], [4, 3, 2, 1])
  
# plotting the data in the 2nd subplot only
axes[1].plot([1, 2, 3, 4], [1, 1, 1, 1])

# %%
x=[1,2,3,3,4,4,5]
y=[2,3,4,5,6,7,8]
z=[1,3,5,6,7,8,9]
ax1=plt.subplot2grid((7,1),(0,0),rowspan=2,colspan=1)
ax2=plt.subplot2grid((7,1),(2,0),rowspan=2,colspan=1)
ax3=plt.subplot2grid((7,1),(4,0),rowspan=2,colspan=1)
ax1.plot(x,y)
ax2.plot(y,z)
ax3.plot(x,z)
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,3,4,5,6]
plt.plot(x,y)
plt.plot(y,x)
plt.legend(["blue","red"])
plt.show()

# %%
x=[1,2,3,4,5,5,6,6]
y=[2,3,4,5,6,7,7,4]
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
x=[1,2,3,3,4,5]
y=[2,4,5,6,7,8]
plt.barh(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
x=[1,1,2,3,4,3,5,3,6,7,2,4,3]
plt.hist(x,bins=[1,2,3,4,5,6,7])
plt.show()

# %%
x=[1,2,3,3,4,5,6]
y=[2,3,4,5,5,6,2]
plt.scatter(x,y)
plt.title("scatterplot")
plt.legend("s")
plt.show()

# %%
x=[20,30,40,50]
e=(0.2,0,0,0)
plt.pie(x,explode=e,shadow=True,labels=[20,30,40,50])
# Out:
# ([<matplotlib.patches.Wedge at 0x267968111f0>,
# ...
#  [Text(1.1712595169567022, 0.5640488843516608, '20'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, '30'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, '40'),
#   Text(0.4772722720983461, -0.9910656780890369, '50')])

# %%
x=[1,2,3,4,5,6]
y=[2,3,4,5,6,7]
z=[2,3,4,5,6,6]
axes=plt.axes(projection="3d")
axes.plot3D(x,y,z)

# %%
##### seaborn visualization

# %%
import seaborn as sns
import numpy as np

# %%
value=np.random.RandomState(10)
value
# Out:
# RandomState(MT19937) at 0x26794BFFC40

# %%
new=value.normal(size=100)
new
# Out:
# array([ 1.3315865 ,  0.71527897, -1.54540029, -0.00838385,  0.62133597,
#        -0.72008556,  0.26551159,  0.10854853,  0.00429143, -0.17460021,
#         0.43302619,  1.20303737, -0.96506567,  1.02827408,  0.22863013,
#         0.44513761, -1.13660221,  0.13513688,  1.484537  , -1.07980489,
#        -1.97772828, -1.7433723 ,  0.26607016,  2.38496733,  1.12369125,
#         1.67262221,  0.09914922,  1.39799638, -0.27124799,  0.61320418,
#        -0.26731719, -0.54930901,  0.1327083 , -0.47614201,  1.30847308,
#         0.19501328,  0.40020999, -0.33763234,  1.25647226, -0.7319695 ,
#         0.66023155, -0.35087189, -0.93943336, -0.48933722, -0.80459114,
#        -0.21269764, -0.33914025,  0.31216994,  0.56515267, -0.14742026,
#        -0.02590534,  0.2890942 , -0.53987907,  0.70816002,  0.84222474,
#         0.2035808 ,  2.39470366,  0.91745894, -0.11227247, -0.36218045,
#        -0.23218226, -0.5017289 ,  1.12878515, -0.69781003, -0.08112218,
# ...

# %%
sns.histplot(new,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df=pd.read_csv(r"C:\Users\SDR\Desktop\data science\iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x=df["SepalLengthCm"].values
x
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
y=df["SepalWidthCm"].values
y
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
#        3. , 4. , 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3. ,
#        3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.1, 3. ,
#        3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3. , 3.8, 3.2, 3.7, 3.3, 3.2, 3.2,
#        3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2. , 3. , 2.2, 2.9, 2.9,
#        3.1, 3. , 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3. , 2.8, 3. ,
#        2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3. , 3.4, 3.1, 2.3, 3. , 2.5, 2.6,
#        3. , 2.6, 2.3, 2.7, 3. , 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3. , 2.9,
#        3. , 3. , 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3. , 2.5, 2.8, 3.2, 3. ,
#        3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3. , 2.8, 3. ,
#        2.8, 3.8, 2.8, 2.8, 2.6, 3. , 3.4, 3.1, 3. , 3.1, 3.1, 3.1, 2.7,
#        3.2, 3.3, 3. , 2.5, 3. , 3.4, 3. ])

# %%
sns.scatterplot(x,y)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.lineplot(x,y)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.histplot(y,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.boxplot(x)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.boxplot(y)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.boxplot(x,y)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.violinplot(x)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.violinplot(y)
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df["Species"])
# Out:
# C:\Users\SDR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>
